# %%
import pandas as pd

# %% [markdown]
# # 003

# %% [markdown]
# ## Decision Tree

# %%
dt_003 = pd.read_csv("./params/003_decision_tree.csv")
dt_003.T
# Out:
#                                0
# criterion          squared_error
# max_depth                     16
# max_leaf_nodes               100
# min_samples_leaf               1
# min_samples_split              2
# random_state                  42
# splitter                    best
# score                   0.645186
# model              Decision Tree

# %% [markdown]
# ## Random Forest

# %%
rf_003 = pd.read_csv("./params/003_random_forest.csv")
rf_003.T
# Out:
#                                0
# max_depth                     16
# max_leaf_nodes               100
# min_samples_leaf               1
# min_samples_split              8
# n_estimators                 200
# n_jobs                        12
# score                   0.676598
# model              Random Forest

# %% [markdown]
# ## XGBoost

# %%
xgb_003 = pd.read_csv("./params/003_xgboost.csv")
xgb_003.T
# Out:
#                                   0
# alpha                             1
# learning_rate                   0.3
# max_depth                         8
# max_leaves                       80
# n_estimators                    350
# num_parallel_tree                10
# objective          reg:squarederror
# predictor             gpu_predictor
# random_state                     42
# tree_method                gpu_hist
# score                      0.841972
# model                       XGBoost

# %% [markdown]
# ## MLP

# %%
mlp_003 = pd.read_csv("./params/003_mlpr.csv")
mlp_003.T
# Out:
#                                 0
# alpha                         0.1
# epsilon                    0.0001
# hidden_layer_sizes  (100, 50, 25)
# learning_rate_init          0.001
# max_iter                      500
# n_iter_no_change               10
# random_state                   42
# tol                        0.0001
# score                    0.746133
# model                         MLP

# %% [markdown]
# # 013

# %%
pd.read_csv("./params/013_decision_tree.csv").T
# Out:
#                                0
# criterion          squared_error
# max_depth                     16
# max_leaf_nodes               100
# min_samples_leaf               1
# min_samples_split              2
# random_state                  42
# splitter                    best
# score                   0.837316
# model              Decision Tree

# %%
pd.read_csv("./params/013_random_forest.csv").T
# Out:
#                                0
# max_depth                     48
# max_leaf_nodes               100
# min_samples_leaf               1
# min_samples_split              8
# n_estimators                 300
# score                   0.849477
# model              Random Forest

# %%
pd.read_csv("./params/013_xgboost.csv").T
# Out:
#                                   0
# alpha                             1
# learning_rate                   0.3
# max_depth                         8
# max_leaves                       80
# n_estimators                    350
# num_parallel_tree                10
# objective          reg:squarederror
# predictor             gpu_predictor
# random_state                     42
# tree_method                gpu_hist
# score                        0.9589
# model                       XGBoost

# %%
pd.read_csv("./params/013_mlpr.csv").T
# Out:
#                                 0
# alpha                         0.1
# epsilon                    0.0001
# hidden_layer_sizes  (100, 50, 25)
# learning_rate_init          0.001
# max_iter                      500
# n_iter_no_change               10
# random_state                   42
# tol                        0.0001
# score                    0.911361
# model                         MLP

# %% [markdown]
# # 023

# %%
dt = pd.read_csv("./params/023_decision_tree.csv").T
rf = pd.read_csv("./params/023_random_forest.csv").T
xg = pd.read_csv("./params/023_xgboost.csv").T
dl = pd.read_csv("./params/023_mlpr.csv").T

# %%
dt
# Out:
#                                0
# criterion          squared_error
# max_depth                     16
# max_leaf_nodes               100
# min_samples_leaf               1
# min_samples_split              2
# random_state                  42
# splitter                    best
# score                   0.424033
# model              Decision Tree

# %%
rf
# Out:
#                                0
# max_depth                     32
# max_leaf_nodes               100
# min_samples_leaf               1
# min_samples_split              2
# n_estimators                 100
# score                   0.452495
# model              Random Forest

# %%
xg
# Out:
#                                   0
# alpha                             1
# learning_rate                   0.3
# max_depth                         6
# max_leaves                       40
# n_estimators                    100
# num_parallel_tree                10
# objective          reg:squarederror
# predictor             gpu_predictor
# random_state                     42
# tree_method                gpu_hist
# score                      0.496075
# model                       XGBoost

# %%
dl
# Out:
#                                 0
# alpha                         0.1
# epsilon                    0.0001
# hidden_layer_sizes  (100, 50, 25)
# learning_rate_init          0.001
# max_iter                      500
# n_iter_no_change               10
# random_state                   42
# tol                        0.0001
# score                    0.432041
# model                         MLP

# %% [markdown]
# # 033

# %%
dt = pd.read_csv("./params/033_decision_tree.csv").T
rf = pd.read_csv("./params/033_random_forest.csv").T
xg = pd.read_csv("./params/033_xgboost.csv").T
dl = pd.read_csv("./params/033_mlpr.csv").T

# %%
dt
# Out:
#                                0
# criterion          squared_error
# max_depth                     16
# max_leaf_nodes                75
# min_samples_leaf               1
# min_samples_split              2
# random_state                  42
# splitter                    best
# score                   0.857412
# model              Decision Tree

# %%
rf
# Out:
#                                0
# max_depth                     32
# max_leaf_nodes               100
# min_samples_leaf               1
# min_samples_split              2
# n_estimators                 200
# score                   0.876828
# model              Random Forest

# %%
xg
# Out:
#                                   0
# alpha                           0.1
# learning_rate                   0.3
# max_depth                         6
# max_leaves                       40
# n_estimators                    100
# num_parallel_tree                10
# objective          reg:squarederror
# predictor             gpu_predictor
# random_state                     42
# tree_method                gpu_hist
# score                       0.91196
# model                       XGBoost

# %%
dl
# Out:
#                                 0
# alpha                         0.1
# epsilon                    0.0001
# hidden_layer_sizes  (100, 50, 25)
# learning_rate_init          0.001
# max_iter                      500
# n_iter_no_change               10
# random_state                   42
# tol                        0.0001
# score                    0.480226
# model                         MLP

# %% [markdown]
# # 043

# %%
dt = pd.read_csv("./params/043_decision_tree.csv").T
rf = pd.read_csv("./params/043_random_forest.csv").T
xg = pd.read_csv("./params/043_xgboost.csv").T
dl = pd.read_csv("./params/043_mlpr.csv").T

# %%
dt
# Out:
#                                0
# criterion          squared_error
# max_depth                     16
# max_leaf_nodes               100
# min_samples_leaf               1
# min_samples_split              2
# random_state                  42
# splitter                    best
# score                   0.658075
# model              Decision Tree

# %%
rf
# Out:
#                                0
# max_depth                     48
# max_leaf_nodes               100
# min_samples_leaf               1
# min_samples_split              8
# n_estimators                 100
# score                    0.69844
# model              Random Forest

# %%
xg
# Out:
#                                   0
# alpha                             1
# learning_rate                   0.3
# max_depth                        16
# max_leaves                       80
# n_estimators                    350
# num_parallel_tree                10
# objective          reg:squarederror
# predictor             gpu_predictor
# random_state                     42
# tree_method                gpu_hist
# score                      0.839943
# model                       XGBoost

# %%
dl
# Out:
#                                 0
# alpha                       0.001
# epsilon                       0.0
# hidden_layer_sizes  (100, 50, 25)
# learning_rate_init          0.001
# max_iter                      500
# n_iter_no_change               10
# random_state                   42
# tol                        0.0001
# score                    0.735427
# model                         MLP

# %% [markdown]
# # 053

# %%
dt = pd.read_csv("./params/053_decision_tree.csv").T
rf = pd.read_csv("./params/053_random_forest.csv").T
xg = pd.read_csv("./params/053_xgboost.csv").T
dl = pd.read_csv("./params/053_mlpr.csv").T

# %%
dt
# Out:
#                                0
# criterion          squared_error
# max_depth                     16
# max_leaf_nodes               100
# min_samples_leaf               1
# min_samples_split             32
# random_state                  42
# splitter                    best
# score                   0.838807
# model              Decision Tree

# %%
rf
# Out:
#                                0
# max_depth                     32
# max_leaf_nodes               100
# min_samples_leaf              10
# min_samples_split             16
# n_estimators                 200
# score                   0.851724
# model              Random Forest

# %%
xg
# Out:
#                                   0
# alpha                             1
# learning_rate                   0.3
# max_depth                         8
# max_leaves                       80
# n_estimators                    350
# num_parallel_tree                10
# objective          reg:squarederror
# predictor             gpu_predictor
# random_state                     42
# tree_method                gpu_hist
# score                      0.956585
# model                       XGBoost

# %%
dl
# Out:
#                                 0
# alpha                         0.1
# epsilon                       0.0
# hidden_layer_sizes  (100, 50, 25)
# learning_rate_init          0.001
# max_iter                      500
# n_iter_no_change               10
# random_state                   42
# tol                        0.0001
# score                    0.898637
# model                         MLP

# %% [markdown]
# # 063

# %%
dt = pd.read_csv("./params/063_decision_tree.csv").T
rf = pd.read_csv("./params/063_random_forest.csv").T
xg = pd.read_csv("./params/063_xgboost.csv").T
dl = pd.read_csv("./params/063_mlpr.csv").T

# %%
dt
# Out:
#                                0
# criterion          squared_error
# max_depth                     16
# max_leaf_nodes               100
# min_samples_leaf               1
# min_samples_split              2
# random_state                  42
# splitter                    best
# score                   0.405531
# model              Decision Tree

# %%
rf
# Out:
#                                0
# max_depth                     16
# max_leaf_nodes               100
# min_samples_leaf               1
# min_samples_split              2
# n_estimators                 200
# score                   0.447854
# model              Random Forest

# %%
xg
# Out:
#                                   0
# alpha                             1
# learning_rate                   0.3
# max_depth                         8
# max_leaves                       40
# n_estimators                    100
# num_parallel_tree                10
# objective          reg:squarederror
# predictor             cpu_predictor
# random_state                     42
# tree_method                    hist
# score                      0.478678
# model                       XGBoost

# %%
dl
# Out:
#                                 0
# alpha                      0.0001
# epsilon                       0.0
# hidden_layer_sizes  (100, 50, 25)
# learning_rate_init          0.001
# max_iter                      200
# n_iter_no_change               10
# random_state                   42
# tol                        0.0001
# score                    0.395627
# model                         MLP

# %% [markdown]
# # 073

# %%
dt = pd.read_csv("./params/073_decision_tree.csv").T
rf = pd.read_csv("./params/073_random_forest.csv").T
xg = pd.read_csv("./params/073_xgboost.csv").T
dl = pd.read_csv("./params/073_mlpr.csv").T

# %%
dt
# Out:
#                                0
# criterion          squared_error
# max_depth                      8
# max_leaf_nodes                75
# min_samples_leaf               1
# min_samples_split              4
# random_state                  42
# splitter                    best
# score                   0.780289
# model              Decision Tree

# %%
rf
# Out:
#                                0
# max_depth                     16
# max_leaf_nodes               100
# min_samples_leaf               1
# min_samples_split              2
# n_estimators                 300
# score                   0.874244
# model              Random Forest

# %%
xg
# Out:
#                                   0
# alpha                          0.01
# learning_rate                   0.3
# max_depth                         6
# max_leaves                       20
# n_estimators                    100
# num_parallel_tree                10
# objective          reg:squarederror
# predictor             cpu_predictor
# random_state                     42
# tree_method                    hist
# score                      0.872267
# model                       XGBoost

# %%
dl
# Out:
#                             0
# alpha                     0.1
# epsilon                   0.0
# hidden_layer_sizes  (100, 50)
# learning_rate_init      0.001
# max_iter                  500
# n_iter_no_change           10
# random_state               42
# tol                    0.0001
# score                0.222183
# model                     MLP

# %% [markdown]
# # 083

# %%
dt = pd.read_csv("./params/083_decision_tree.csv").T
rf = pd.read_csv("./params/083_random_forest.csv").T
xg = pd.read_csv("./params/083_xgboost.csv").T
dl = pd.read_csv("./params/083_mlpr.csv").T

# %%
dt
# Out:
#                                0
# criterion          squared_error
# max_depth                     16
# max_leaf_nodes               100
# min_samples_leaf               5
# min_samples_split              2
# random_state                  42
# splitter                    best
# score                    0.67978
# model              Decision Tree

# %%
rf
# Out:
#                                0
# max_depth                     32
# max_leaf_nodes               100
# min_samples_leaf               1
# min_samples_split              8
# n_estimators                 200
# score                   0.700367
# model              Random Forest

# %%
xg
# Out:
#                                   0
# alpha                          0.01
# learning_rate                   0.3
# max_depth                        16
# max_leaves                       80
# n_estimators                    350
# num_parallel_tree                10
# objective          reg:squarederror
# predictor             gpu_predictor
# random_state                     42
# tree_method                gpu_hist
# score                      0.839635
# model                       XGBoost

# %%
dl
# Out:
#                                 0
# alpha                       0.001
# epsilon                    0.0001
# hidden_layer_sizes  (100, 50, 25)
# learning_rate_init          0.001
# max_iter                      500
# n_iter_no_change               10
# random_state                   42
# tol                        0.0001
# score                    0.609696
# model                         MLP

# %% [markdown]
# # 093

# %%
dt = pd.read_csv("./params/093_decision_tree.csv").T
rf = pd.read_csv("./params/093_random_forest.csv").T
xg = pd.read_csv("./params/093_xgboost.csv").T
dl = pd.read_csv("./params/093_mlpr.csv").T

# %%
dt
# Out:
#                                0
# criterion          squared_error
# max_depth                     16
# max_leaf_nodes               100
# min_samples_leaf               5
# min_samples_split              2
# random_state                  42
# splitter                    best
# score                   0.835666
# model              Decision Tree

# %%
rf
# Out:
#                                0
# max_depth                     16
# max_leaf_nodes               100
# min_samples_leaf               1
# min_samples_split              8
# n_estimators                 100
# score                   0.846969
# model              Random Forest

# %%
xg
# Out:
#                                   0
# alpha                           0.1
# learning_rate                   0.3
# max_depth                         8
# max_leaves                       80
# n_estimators                    350
# num_parallel_tree                10
# objective          reg:squarederror
# predictor             gpu_predictor
# random_state                     42
# tree_method                gpu_hist
# score                      0.957929
# model                       XGBoost

# %%
dl
# Out:
#                                 0
# alpha                      0.0001
# epsilon                       0.0
# hidden_layer_sizes  (100, 50, 25)
# learning_rate_init          0.001
# max_iter                      750
# n_iter_no_change               10
# random_state                   42
# tol                        0.0001
# score                    0.913447
# model                         MLP

# %% [markdown]
# # 103

# %%
dt = pd.read_csv("./params/103_decision_tree.csv").T
rf = pd.read_csv("./params/103_random_forest.csv").T
xg = pd.read_csv("./params/103_xgboost.csv").T
dl = pd.read_csv("./params/103_mlpr.csv").T

# %%
dt
# Out:
#                                0
# criterion          squared_error
# max_depth                     16
# max_leaf_nodes               100
# min_samples_leaf               1
# min_samples_split              8
# random_state                  42
# splitter                    best
# score                   0.435162
# model              Decision Tree

# %%
rf
# Out:
#                                0
# max_depth                     32
# max_leaf_nodes               100
# min_samples_leaf               1
# min_samples_split              8
# n_estimators                 300
# score                   0.471526
# model              Random Forest

# %%
xg
# Out:
#                                   0
# alpha                             1
# learning_rate                   0.3
# max_depth                         8
# max_leaves                       80
# n_estimators                    100
# num_parallel_tree                10
# objective          reg:squarederror
# predictor             gpu_predictor
# random_state                     42
# tree_method                gpu_hist
# score                      0.527537
# model                       XGBoost

# %%
dl
# Out:
#                                 0
# alpha                      0.0001
# epsilon                    0.0001
# hidden_layer_sizes  (100, 50, 25)
# learning_rate_init          0.001
# max_iter                      500
# n_iter_no_change               10
# random_state                   42
# tol                        0.0001
# score                    0.353104
# model                         MLP

# %% [markdown]
# # 113

# %%
dt = pd.read_csv("./params/113_decision_tree.csv").T
rf = pd.read_csv("./params/113_random_forest.csv").T
xg = pd.read_csv("./params/113_xgboost.csv").T
dl = pd.read_csv("./params/113_mlpr.csv").T

# %%
dt
# Out:
#                                0
# criterion          squared_error
# max_depth                     16
# max_leaf_nodes               100
# min_samples_leaf               1
# min_samples_split              2
# random_state                  42
# splitter                    best
# score                   0.852504
# model              Decision Tree

# %%
rf
# Out:
#                                0
# max_depth                     16
# max_leaf_nodes               100
# min_samples_leaf               1
# min_samples_split              2
# n_estimators                 200
# score                   0.881354
# model              Random Forest

# %%
xg
# Out:
#                                   0
# alpha                             1
# learning_rate                   0.3
# max_depth                         6
# max_leaves                       20
# n_estimators                    100
# num_parallel_tree                10
# objective          reg:squarederror
# predictor             gpu_predictor
# random_state                     42
# tree_method                gpu_hist
# score                      0.908001
# model                       XGBoost

# %%
dl
# Out:
#                            0
# alpha                  0.001
# epsilon               0.0001
# hidden_layer_sizes       100
# learning_rate_init       0.1
# max_iter                 200
# n_iter_no_change          10
# random_state              42
# tol                   0.0001
# score               0.484404
# model                    MLP

# %% [markdown]
# # 123

# %%
dt = pd.read_csv("./params/123_decision_tree.csv").T
rf = pd.read_csv("./params/123_random_forest.csv").T
xg = pd.read_csv("./params/123_xgboost.csv").T
dl = pd.read_csv("./params/123_mlpr.csv").T

# %%
dt
# Out:
#                                0
# criterion          squared_error
# max_depth                     16
# max_leaf_nodes               100
# min_samples_leaf               1
# min_samples_split              8
# random_state                  42
# splitter                    best
# score                   0.696049
# model              Decision Tree

# %%
rf
# Out:
#                                0
# max_depth                     16
# max_leaf_nodes               100
# min_samples_leaf               1
# min_samples_split              2
# n_estimators                 100
# score                   0.724869
# model              Random Forest

# %%
xg
# Out:
#                                   0
# alpha                             1
# learning_rate                   0.3
# max_depth                        16
# max_leaves                       80
# n_estimators                    350
# num_parallel_tree                10
# objective          reg:squarederror
# predictor             gpu_predictor
# random_state                     42
# tree_method                gpu_hist
# score                       0.86534
# model                       XGBoost

# %%
dl
# Out:
#                                 0
# alpha                      0.0001
# epsilon                       0.0
# hidden_layer_sizes  (100, 50, 25)
# learning_rate_init          0.001
# max_iter                      500
# n_iter_no_change               10
# random_state                   42
# tol                        0.0001
# score                    0.699075
# model                         MLP

# %% [markdown]
# # 133

# %%
dt = pd.read_csv("./params/133_decision_tree.csv").T
rf = pd.read_csv("./params/133_random_forest.csv").T
xg = pd.read_csv("./params/133_xgboost.csv").T
dl = pd.read_csv("./params/133_mlpr.csv").T

# %%
dt
# Out:
#                                0
# criterion          squared_error
# max_depth                     16
# max_leaf_nodes               100
# min_samples_leaf               5
# min_samples_split             32
# random_state                  42
# splitter                    best
# score                   0.835028
# model              Decision Tree

# %%
rf
# Out:
#                                0
# max_depth                     16
# max_leaf_nodes               100
# min_samples_leaf               5
# min_samples_split              2
# n_estimators                 100
# score                    0.84864
# model              Random Forest

# %%
xg
# Out:
#                                   0
# alpha                             1
# learning_rate                   0.3
# max_depth                         8
# max_leaves                       80
# n_estimators                    350
# num_parallel_tree                10
# objective          reg:squarederror
# predictor             gpu_predictor
# random_state                     42
# tree_method                gpu_hist
# score                      0.956949
# model                       XGBoost

# %%
dl
# Out:
#                                 0
# alpha                         0.1
# epsilon                    0.0001
# hidden_layer_sizes  (100, 50, 25)
# learning_rate_init          0.001
# max_iter                      900
# n_iter_no_change               10
# random_state                   42
# tol                        0.0001
# score                    0.899093
# model                         MLP

# %% [markdown]
# # 143

# %%
dt = pd.read_csv("./params/143_decision_tree.csv").T
rf = pd.read_csv("./params/143_random_forest.csv").T
xg = pd.read_csv("./params/143_xgboost.csv").T
dl = pd.read_csv("./params/143_mlpr.csv").T

# %%
dt
# Out:
#                                0
# criterion          squared_error
# max_depth                     16
# max_leaf_nodes               100
# min_samples_leaf               1
# min_samples_split              2
# random_state                  42
# splitter                    best
# score                   0.436838
# model              Decision Tree

# %%
rf
# Out:
#                                0
# max_depth                     48
# max_leaf_nodes               100
# min_samples_leaf               1
# min_samples_split              8
# n_estimators                 200
# score                   0.478545
# model              Random Forest

# %%
xg
# Out:
#                                   0
# alpha                             1
# learning_rate                   0.3
# max_depth                         8
# max_leaves                       80
# n_estimators                    250
# num_parallel_tree                10
# objective          reg:squarederror
# predictor             gpu_predictor
# random_state                     42
# tree_method                gpu_hist
# score                      0.553058
# model                       XGBoost

# %%
dl
# Out:
#                                 0
# alpha                         0.1
# epsilon                       0.0
# hidden_layer_sizes  (100, 50, 25)
# learning_rate_init          0.001
# max_iter                      500
# n_iter_no_change               10
# random_state                   42
# tol                        0.0001
# score                    0.357856
# model                         MLP

# %% [markdown]
# # 153

# %%
dt = pd.read_csv("./params/153_decision_tree.csv").T
rf = pd.read_csv("./params/153_random_forest.csv").T
xg = pd.read_csv("./params/153_xgboost.csv").T
dl = pd.read_csv("./params/153_mlpr.csv").T

# %%
dt
# Out:
#                                0
# criterion          squared_error
# max_depth                     16
# max_leaf_nodes               100
# min_samples_leaf               1
# min_samples_split             16
# random_state                  42
# splitter                    best
# score                    0.92559
# model              Decision Tree

# %%
rf
# Out:
#                                0
# max_depth                     48
# max_leaf_nodes               100
# min_samples_leaf               1
# min_samples_split              8
# n_estimators                 300
# score                   0.933927
# model              Random Forest

# %%
xg
# Out:
#                                   0
# alpha                             1
# learning_rate                   0.3
# max_depth                        16
# max_leaves                       40
# n_estimators                    100
# num_parallel_tree                10
# objective          reg:squarederror
# predictor             gpu_predictor
# random_state                     42
# tree_method                gpu_hist
# score                      0.956869
# model                       XGBoost

# %%
dl
# Out:
#                            0
# alpha                 0.0001
# epsilon                  0.0
# hidden_layer_sizes       100
# learning_rate_init     0.001
# max_iter                1500
# n_iter_no_change          10
# random_state              42
# tol                   0.0001
# score               0.617788
# model                    MLP
