# %% [markdown]
# # Get feature importance / SHAP values

# %%
import numpy as np
import pandas as pd
import shap
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from matplotlib import pyplot as pl
import ml_help
from time import time
import seaborn as sns
sns.set_theme()

# %%
df = pd.read_csv("./data/yonge_count_incidents.csv.zip")
df
# Out:
#       total_count  dist_from_mid_point  is_north_from_mid_point  visibility  \
# 0             204             0.544386                        0        10.0
# 1             175             0.920430                        0        10.0
# 2             174             0.775626                        0        10.0
# 3             213             0.544386                        0        10.0
# 4             213             0.920430                        0        10.0
# ...           ...                  ...                      ...         ...
# 2139          300             1.808736                        0        10.0
# 2140          270             1.700176                        0        10.0
# 2141          265             1.537153                        0        10.0
# 2142          263             1.373344                        0        10.0
# 2143          246             1.145063                        0        10.0
#
#       temperature  FeelsLike  humidity  windSpeed  cloudsAll  rain1h  snow1h  \
# 0           20.94      21.05        75       2.57         75     0.0     0.0
# 1           20.94      21.05        75       2.57         75     0.0     0.0
# 2           20.94      21.05        75       2.57         75     0.0     0.0
# 3           20.98      21.04        73       2.57         75     0.0     0.0
# 4           20.98      21.04        73       2.57         75     0.0     0.0
# ...           ...        ...       ...        ...        ...     ...     ...
# 2139        19.51      19.03        58       1.54          0     0.0     0.0
# 2140        19.51      19.03        58       1.54          0     0.0     0.0
# 2141        19.51      19.03        58       1.54          0     0.0     0.0
# 2142        19.51      19.03        58       1.54          0     0.0     0.0
# 2143        19.51      19.03        58       1.54          0     0.0     0.0
#
#       cloudy  clear  atmosphere  snowy  rainy  month  day_of_week  hour  \
# 0          1      0           0      0      0      8            3     7
# 1          1      0           0      0      0      8            3     7
# 2          1      0           0      0      0      8            3     7
# 3          1      0           0      0      0      8            3     8
# 4          1      0           0      0      0      8            3     8
# ...      ...    ...         ...    ...    ...    ...          ...   ...
# 2139       0      1           0      0      0     10            1    18
# 2140       0      1           0      0      0     10            1    18
# 2141       0      1           0      0      0     10            1    18
# 2142       0      1           0      0      0     10            1    18
# 2143       0      1           0      0      0     10            1    18
#
#       minute
# 0         45
# 1         45
# 2         45
# 3          0
# 4          0
# ...      ...
# 2139       0
# 2140       0
# 2141       0
# 2142       0
# 2143       0
#
# [2144 rows x 20 columns]

# %%
X = transformed_df.drop("total_count",axis=1)
y = transformed_df["total_count"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=42) # 0.25 x 0.80 = 0.20

# %% [markdown]
# # XGBoost

# %%
import xgboost as xgb

params = ml_help.params_to_dict("113_xgboost")
model = xgb.XGBRegressor(**params)

print("Fitting...")
start = time()
model.fit(X_train, y_train)
end = time()
print(f"Fitting... OK! Took {end - start} seconds")

print("Explaining...")
start = time()
explainer = shap.TreeExplainer(model)
end = time()
print(f"Explaining... OK! Took {end - start} seconds")

print("Calculating shap values...")
start = time()
shap_values = explainer.shap_values(X_test)
end = time()
print(f"Calculating shap values... OK! Took {end - start} seconds")

shap.summary_plot(shap_values, X_test, max_display=10, show=False)
xgboost_fig = pl.gcf()
pl.savefig("./plots/116_xgboost.eps", format="eps", bbox_inches="tight")
pl.savefig("./plots/116_xgboost.png", bbox_inches="tight")
# Out:
# Fitting...
# Fitting... OK! Took 0.8139314651489258 seconds
# Explaining...
# Explaining... OK! Took 0.6275568008422852 seconds
# Calculating shap values...
# Calculating shap values... OK! Took 0.13651156425476074 seconds
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

params = ml_help.params_to_dict("113_random_forest")
model = RandomForestRegressor(**params)

print("Fitting...")
start = time()
model.fit(X_train, y_train)
end = time()
print(f"Fitting... OK! Took {end - start} seconds")

print("Explaining...")
start = time()
explainer = shap.TreeExplainer(model)
end = time()
print(f"Explaining... OK! Took {end - start} seconds")

print("Calculating shap values...")
start = time()
shap_values = explainer.shap_values(X_test)
end = time()
print(f"Calculating shap values... OK! Took {end - start} seconds")

shap.summary_plot(shap_values, X_test, max_display=10, show=False)
pl.savefig("./plots/116_random_forest.eps", format="eps", bbox_inches="tight")
pl.savefig("./plots/116_random_forest.png", bbox_inches="tight")
# Out:
# Fitting...
# Fitting... OK! Took 1.0487167835235596 seconds
# Explaining...
# Explaining... OK! Took 0.01214599609375 seconds
# Calculating shap values...
# Calculating shap values... OK! Took 1.5956716537475586 seconds
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

params = ml_help.params_to_dict("113_decision_tree")
model = DecisionTreeRegressor(**params)

print("Fitting...")
start = time()
model.fit(X_train, y_train)
end = time()
print(f"Fitting... OK! Took {end - start} seconds")

print("Explaining...")
start = time()
explainer = shap.TreeExplainer(model)
end = time()
print(f"Explaining... OK! Took {end - start} seconds")

print("Calculating shap values...")
start = time()
shap_values = explainer.shap_values(X_test)
end = time()
print(f"Calculating shap values... OK! Took {end - start} seconds")

shap.summary_plot(shap_values, X_test, max_display=10, show=False)
pl.savefig("./plots/116_decision_tree.eps", format="eps", bbox_inches="tight")
pl.savefig("./plots/116_decision_tree.png", bbox_inches="tight")
# Out:
# Fitting...
# Fitting... OK! Took 0.005167722702026367 seconds
# Explaining...
# Explaining... OK! Took 0.0008940696716308594 seconds
# Calculating shap values...
# Calculating shap values... OK! Took 0.0032618045806884766 seconds
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %% [markdown]
# # MLP

# %%
from sklearn.neural_network import MLPRegressor
import warnings

X_train_summary = shap.kmeans(X_train, 10)

params = ml_help.params_to_dict("113_mlpr")
model = MLPRegressor(**params)

print("Fitting...")
start = time()
model.fit(X_train, y_train)
end = time()
print(f"Fitting... OK! Took {end - start} seconds")

print("Explaining...")
start = time()
explainer = shap.KernelExplainer(model.predict, X_train_summary)
end = time()
print(f"Explaining... OK! Took {end - start} seconds")

print("Calculating shap values...")
start = time()
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    shap_values = explainer.shap_values(X_test)
end = time()
print(f"Calculating shap values... OK! Took {end - start} seconds")

shap.summary_plot(shap_values, X_test, max_display=10, show=False)
pl.savefig("./plots/116_mlp.eps", format="eps", bbox_inches="tight")
pl.savefig("./plots/116_mlp.png", bbox_inches="tight")
# Out:
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
# Fitting...
# Fitting... OK! Took 3.403066873550415 seconds
# Explaining...
# Explaining... OK! Took 0.0005257129669189453 seconds
# Calculating shap values...
# X does not have valid feature names, but MLPRegressor was fitted with feature names
#   0%|          | 0/429 [00:00<?, ?it/s]
# Calculating shap values... OK! Took 75.44087719917297 seconds
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
