# %% [markdown]
# # Import packages

# %%
import pandas as pd
import ml_help
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
plot_label="Speed (km/h)"
sns.set_theme()

# %% [markdown]
# # Load data set

# %%
df = pd.read_csv("./data/yonge_flow_weather_incidents.csv.zip")
df

# %% [markdown]
# # Split data set into train, validate and test

# %%
X = df.drop("currentSpeed",axis=1)
y = df["currentSpeed"]

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train,y_train,test_size=0.25, random_state=42)

# %% [markdown]
# # Run ML tasks

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression

file_name = "141_linear_regression"
model_name = "Linear Regression"

model_train, model_metrics_train = ml_help.train_and_test(file_name, model_name, LinearRegression(), X_train, X_val, y_train, y_val, plot_label)
# Out:
# Fitting model...
# Fitting model... OK! Took 0.24386382102966309 seconds
#
# model Linear Regression
# r2 0.2635042409853161
# mae 2.565188173417334
# mse 10.235336968917744
# rmse 3.1992713184282673
# mape 150560981076329.2
# time_to_fit 0.24386382102966309
# time_to_predict 0.008720636367797852
#
# Dumping model...
# Dumping model... OK! Took 0.0017538070678710938 seconds
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

file_name = "141_logistic_regression"
model_name = "Logistic Regression"

model_train, model_metrics_train = ml_help.train_and_test(file_name, model_name, LogisticRegression(), X_train, X_val, y_train, y_val, plot_label)
# Out:
# Fitting model...
# /home/felipe/miniconda3/envs/rapids/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fitting model... OK! Took 5.176189422607422 seconds
#
# model Logistic Regression
# r2 -0.4602082221157542
# mae 2.8555632342778163
# mse 20.293020041465102
# rmse 4.5047774685843365
# mape 157054986739410.44
# time_to_fit 5.176189422607422
# time_to_predict 0.011509418487548828
#
# Dumping model...
# Dumping model... OK! Took 0.0022330284118652344 seconds
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Lasso

# %%
from sklearn.linear_model import Lasso

file_name = "141_lasso"
model_name = "Lasso"

model_train, model_metrics_train = ml_help.train_and_test(file_name, model_name, Lasso(), X_train, X_val, y_train, y_val, plot_label)
# Out:
# Fitting model...
# Fitting model... OK! Took 0.07500672340393066 seconds
#
# model Lasso
# r2 0.11138162838973331
# mae 3.103074683046894
# mse 12.349437670041914
# rmse 3.514176670294468
# mape 155624788732548.4
# time_to_fit 0.07500672340393066
# time_to_predict 0.007032632827758789
#
# Dumping model...
# Dumping model... OK! Took 0.0016968250274658203 seconds
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Elastic Net

# %%
from sklearn.linear_model import ElasticNet

file_name = "141_elastic_net"
model_name = "Elastic Net"

model_train, model_metrics_train = ml_help.train_and_test(file_name, model_name, ElasticNet(), X_train, X_val, y_train, y_val, plot_label)
# Out:
# Fitting model...
# Fitting model... OK! Took 0.07320284843444824 seconds
#
# model Elastic Net
# r2 0.16749863033926748
# mae 2.9517485161981973
# mse 11.5695602333988
# rmse 3.4014056261197076
# mape 155423946966986.62
# time_to_fit 0.07320284843444824
# time_to_predict 0.006990909576416016
#
# Dumping model...
# Dumping model... OK! Took 0.0016934871673583984 seconds
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

file_name = "141_random_forest"
model_name = "Random Forest"

model_train, model_metrics_train = ml_help.train_and_test(file_name, model_name, RandomForestRegressor(), X_train, X_val, y_train, y_val, plot_label)
# Out:
# Fitting model...
# Fitting model... OK! Took 40.68569755554199 seconds
#
# model Random Forest
# r2 0.6571450740793263
# mae 1.5083419275955556
# mse 4.76477380256233
# rmse 2.18283618317141
# mape 15078236379341.666
# time_to_fit 40.68569755554199
# time_to_predict 0.4018270969390869
#
# Dumping model...
# Dumping model... OK! Took 46.40651845932007 seconds
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

file_name = "141_decision_tree"
model_name = "Decision Tree"

model_train, model_metrics_train = ml_help.train_and_test(file_name, model_name, DecisionTreeRegressor(), X_train, X_val, y_train, y_val, plot_label)
# Out:
# Fitting model...
# Fitting model... OK! Took 0.6430466175079346 seconds
#
# model Decision Tree
# r2 0.41476073019133897
# mae 1.5639253628196268
# mse 8.133273084897136
# rmse 2.851889388615403
# mape 8140045044420.775
# time_to_fit 0.6430466175079346
# time_to_predict 0.010785341262817383
#
# Dumping model...
# Dumping model... OK! Took 0.634223222732544 seconds
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### XGBoost

# %%
import xgboost as xgb

file_name = "141_xgboost"
model_name = "XGBoost"

xgb_params = {"objective": "reg:squarederror", "tree_method": "gpu_hist"}

model_train, model_metrics_train = ml_help.train_and_test(file_name, model_name, xgb.XGBRegressor(**xgb_params), X_train, X_val, y_train, y_val, plot_label)
# Out:
# Fitting model...
# Fitting model... OK! Took 0.5267655849456787 seconds
#
# model XGBoost
# r2 0.588269217364809
# mae 1.8008147353450683
# mse 5.721965468457484
# rmse 2.392063015151876
# mape 40000939842681.37
# time_to_fit 0.5267655849456787
# time_to_predict 0.03931140899658203
#
# Dumping model...
# Dumping model... OK! Took 0.06780481338500977 seconds
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### MLP

# %%
from sklearn.neural_network import MLPRegressor

file_name = "141_mlpr"
model_name = "MLP"

model_train, model_metrics_train = ml_help.train_and_test(file_name, model_name, MLPRegressor(), X_train, X_val, y_train, y_val, plot_label)
# Out:
# Fitting model...
# Fitting model... OK! Took 60.28939986228943 seconds
#
# model MLP
# r2 0.470146223072892
# mae 2.059823324099945
# mse 7.363561683448334
# rmse 2.713588340822597
# mape 66925661266982.79
# time_to_fit 60.28939986228943
# time_to_predict 0.019277095794677734
#
# Dumping model...
# Dumping model... OK! Took 0.013941764831542969 seconds
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
