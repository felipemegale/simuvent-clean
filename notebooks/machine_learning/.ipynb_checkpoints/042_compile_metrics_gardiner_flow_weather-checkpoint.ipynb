# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme()

# %%
elastic_net = pd.read_csv("./metrics/041_elastic_net.csv.zip")
lasso = pd.read_csv("./metrics/041_lasso.csv.zip")
linear_regression = pd.read_csv("./metrics/041_linear_regression.csv.zip")
logistic_regression = pd.read_csv("./metrics/041_logistic_regression.csv.zip")
random_forest = pd.read_csv("./metrics/041_random_forest.csv.zip")
decision_tree = pd.read_csv("./metrics/041_decision_tree.csv.zip")
mlp = pd.read_csv("./metrics/041_mlpr.csv.zip")
xgboost = pd.read_csv("./metrics/041_xgboost.csv.zip")

# %%
metrics = pd.concat([elastic_net,lasso,
                     linear_regression,logistic_regression,
                     random_forest,decision_tree,mlp,xgboost])

# %%
metrics.sort_values("r2",ascending=False,inplace=True)

# %%
metrics
# Out:
#                  model        r2        mae         mse       rmse      mape  \
# 0        Random Forest  0.893517   2.129409   18.093910   4.253694  0.029974
# 0        Decision Tree  0.849152   1.856735   25.632488   5.062854  0.026205
# 0              XGBoost  0.845946   2.981860   26.177359   5.116381  0.040614
# 0                  MLP  0.682925   4.756700   53.878353   7.340187  0.064513
# 0    Linear Regression  0.388856   7.533094  103.847321  10.190551  0.103259
# 0                Lasso  0.320930   7.925828  115.389641  10.741957  0.110917
# 0          Elastic Net  0.306061   8.142928  117.916145  10.858920  0.114664
# 0  Logistic Regression -2.941889  21.985722  669.817383  25.880831  0.251422
#
#    time_to_fit  time_to_predict
# 0     4.207664         0.267096
# 0     0.353466         0.009171
# 0     0.380881         0.021596
# 0    45.597200         0.023200
# 0     0.111757         0.016404
# 0     0.038465         0.013947
# 0     0.040847         0.012194
# 0     0.407291         0.014443

# %%
metrics.to_csv("./metrics/042_initial_metrics.csv.zip",index=False,compression="zip")

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

sns.barplot(ax=axes[0, 0], data=metrics, x='model', y='r2',hue="model",dodge=False)
sns.barplot(ax=axes[0, 1], data=metrics, x='model', y='mae',hue="model",dodge=False)
sns.barplot(ax=axes[0, 2], data=metrics, x='model', y='mse',hue="model",dodge=False)
sns.barplot(ax=axes[1, 0], data=metrics, x='model', y='rmse',hue="model",dodge=False)
sns.barplot(ax=axes[1, 1], data=metrics, x='model', y='mape',hue="model",dodge=False)
sns.barplot(ax=axes[1, 2], data=metrics, x='model', y='time_to_fit',hue="model",dodge=False)

axes[0, 0].set(xlabel="Model",xticklabels=[])
axes[0, 0].set(ylabel="R2")
axes[0, 0].get_legend().remove()

axes[0, 1].set(xlabel="Model",xticklabels=[])
axes[0, 1].set(ylabel="MAE")
axes[0, 1].get_legend().remove()

axes[0, 2].set(xlabel="Model",xticklabels=[])
axes[0, 2].set(ylabel="MSE")
axes[0, 2].legend(loc='center left', bbox_to_anchor=(1, 0.5))

axes[1, 0].set(xlabel="Model",xticklabels=[])
axes[1, 0].set(ylabel="RMSE")
axes[1, 0].get_legend().remove()

axes[1, 1].set(xlabel="Model",xticklabels=[])
axes[1, 1].set(ylabel="MAPE")
axes[1, 1].get_legend().remove()

axes[1, 2].set(xlabel="Model",xticklabels=[])
axes[1, 2].set(ylabel="Time to fit (log)", yscale="log")
axes[1, 2].get_legend().remove()

plt.savefig("./plots/042_gardiner_flow_weather_metrics.eps",format="eps",bbox_inches="tight")
plt.savefig("./plots/042_gardiner_flow_weather_metrics.png",bbox_inches="tight")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
