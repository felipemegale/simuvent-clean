# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme()

# %%
df = pd.read_csv("../../../csv/v2/050_gardiner_flow_processed.csv.zip")

# %%
ax = sns.histplot(data=df,x="currentSpeed",binwidth=3,kde=True)
ax.set(xlabel="Current Speed (km/h)")

plt.savefig("./plots/011_current_speed_histogram.eps",format="eps",bbox_inches="tight")
plt.savefig("./plots/011_current_speed_histogram.png",bbox_inches="tight")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
